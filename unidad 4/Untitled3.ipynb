# %% [markdown]
# Probabilidad Y estadistica:Distribuciones
#
# Unidad 4
#
# Alumno Erik Manuel Vizcarra Segovia
#
# Faciilitador Dr. Jose Gabriel Rodrigues Rivas
#
# Ejercicio 1
#
# Una revision de los pesos de 500 estudiantes del ITD, evidenció que la media es de 70 kilogramos y la desviacion estandar es de 4 kilogramos. Suponiendo que los valores se distribuyen normalmente. Hallar lo siguiente:
#
# La probabilidad de estudiantes que pesan mas de 68 y menos de 72 kg. Cuantos estudiantes pesan mas de 68 y menos de 72 kg.
#
# Normal mente se utiliza
#
# norm.rvs()para calcular numero aleatorios
#
# norm.pdf()para calcular la dencidad de probabilidad
#
# norm.cdf()Para calcular la probabilidad
#
# norm.ppf()Para calcular el valor de la a partir de una probabilidad , es la funcion inversa de cdf()

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
# Generar Datos para la distribución normal

media = 70
desv_std = 4
num_datos = 500

#Generar datos de manera aleatoria
datos = np.random.normal(media, desv_std, num_datos)
datos[0:50]
# Out:
# array([78.05146812, 68.21817021, 72.4243219 , 75.42881347, 65.734025  ,
#        75.79077026, 74.45838714, 70.22279951, 66.47846346, 77.7081679 ,
#        80.56135354, 69.96921484, 68.02480925, 70.96002708, 64.51683443,
#        70.75756648, 70.06153304, 69.0083936 , 69.41541462, 67.67393266,
#        71.52254923, 74.57133705, 70.04389211, 70.79952093, 64.73269743,
#        61.33084059, 72.06127548, 72.35988429, 72.18442869, 77.78478964,
#        66.48472321, 67.90685372, 73.18950947, 71.48122694, 70.20189426,
#        65.96091929, 74.3139246 , 64.89330944, 74.29299464, 74.21295172,
#        63.71305886, 65.84630906, 72.02850813, 66.96348941, 70.18243096,
#        73.16256346, 74.58321996, 75.77367948, 58.91706304, 68.17312749])

# %%
# Graficar histograma
plt.figure(figsize=(6,4))
plt.hist(datos, bins=15, alpha=0.4, color='b')
plt.title('Distribucion normal')
plt.xlabel('Peso (kg)De los estudiantes')
plt.grid(True)
plt.show()

# %%
# crear un rango de valores para crear uan densidad
# crear un rango de valores para crear uan densidad
x = np.linspace(datos - 3 * desv_std, media + 3 * desv_std, num_datos)
# calcular la PDF de la distribuvion normal
pdf = 1 / (desv_std * np.sqrt(2 * np.pi)) * np.exp(-(x - media)**2 / (2 * desv_std**2))

# %%
#Para no imprimir los 500 valores solos los primeros 50
print("Imprimir los primero 50 valores de x",x[0:50],", Y los primero 50 valores de pdf",pdf[0:50])
# Out:
# Imprimir los primero 50 valores de x [[66.05146812 56.21817021 60.4243219  ... 51.52548991 57.86925345
#   62.70793509]
#  [66.0834291  56.2698372  60.46755973 ... 51.58656107 57.91761166
#   62.74659654]
#  [66.11539009 56.32150419 60.51079756 ... 51.64763224 57.96596986
#   62.785258  ]
#  ...
#  [67.55363444 58.6465189  62.4565     ... 54.39583455 60.14208929
#   64.52502337]
#  [67.58559543 58.6981859  62.49973783 ... 54.45690571 60.1904475
#   64.56368482]
#  [67.61755642 58.74985289 62.54297566 ... 54.51797687 60.23880571
#   64.60234627]] , Y los primero 50 valores de pdf [[6.12709991e-02 2.63667581e-04 5.68082824e-03 ... 2.32662232e-06
#   1.00393599e-03 1.89315208e-02]
#  [6.17542097e-02 2.75643905e-04 5.82940880e-03 ... 2.49631902e-06
#   1.04135110e-03 1.92671526e-02]
#  [6.22372576e-02 2.88116144e-04 5.98117654e-03 ... 2.67776860e-06
#   1.08000276e-03 1.96069029e-02]
#  ...
#  [8.27232229e-02 1.77597484e-03 1.68484746e-02 ... 4.94625495e-05
#   4.78601094e-03 3.90870848e-02]
#  [8.31258077e-02 1.84214116e-03 1.71944557e-02 ... 5.24919349e-05
#   4.93039264e-03 3.96057694e-02]
#  [8.35250189e-02 1.91045383e-03 1.75454913e-02 ... 5.56938741e-05
#   5.07838768e-03 4.01275881e-02]]

# %%
# visualizar la PDF
plt.figure(figsize=(6,4))
plt.plot(x, pdf, label='normal:(media:{};ds:{})'.format(np.round(media,2), np.round(desv_std,2)))
plt.title('Funcion de densidad de probabilidad (PDF)- Distribucion normal')
plt.xlabel('Peso (kg)De los estudiantes')
plt.ylabel('Densidad de Probabilidad')
plt.legend()
plt.grid(True)
plt.show()

# %%
#Graficar Hostograma
plt.figure(figsize=(6,4))
plt.hist(datos, bins=15, alpha=0.4, density=True, color='b')

plt.title('Distribucion normal')
plt.xlabel('Peso (kg)De los estudiantes')
plt.grid(True)
plt.show()
