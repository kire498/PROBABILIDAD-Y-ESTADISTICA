# %% [markdown]
# <a href="https://colab.research.google.com/github/kire498/PROBABILIDAD-Y-ESTADISTICA/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **UNIDAD 1**
#
# Probabilidad y Estadistica
#
# Practica: 4-Tabla de frecuencias y regla de Sturges.
#
# Dr. Jose Gabriel Rodriguez Rivas.
#
# Alumno: Erik Manuel Vizcarra Segovia
#
# **TABLA DE FRECUENCIAS**

# %%
import random

# %%
# basado en el LIBRO estadística para administración pagina 12
# creamos una lista vacia que representa la edad de 100 personas

edades= []

# Hacemos un ciclo para generar 100 números aleatorios que representan la edad de las personas
for i in range(100):
    # generamos un número aleatorio con la funcion randint y lo guardamos en la variable
    # numero_aleatorio
    numero_aleatorio = random.randint( 18, 70)
    # Agregamos el número aleatorio a la lista de valores
    edades.append(numero_aleatorio)

print(edades)
# Out:
# [51, 56, 27, 19, 21, 59, 54, 44, 39, 70, 46, 25, 41, 42, 36, 24, 42, 33, 41, 41, 65, 54, 58, 18, 60, 62, 33, 57, 50, 49, 70, 46, 31, 50, 42, 44, 38, 65, 70, 19, 45, 32, 31, 59, 47, 65, 39, 36, 38, 40, 62, 37, 42, 26, 58, 67, 39, 70, 24, 61, 26, 18, 26, 61, 40, 30, 24, 38, 41, 61, 47, 27, 50, 65, 35, 60, 59, 42, 26, 52, 59, 69, 58, 42, 56, 56, 26, 61, 42, 52, 34, 65, 43, 46, 63, 34, 67, 30, 25, 23]

# %%
import pandas as pd

# %%
# Crear un DataFrame de pandas con los números aleatorios
df = pd.DataFrame(edades, columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    51
# 1    56
# 2    27
# 3    19
# 4    21

# %%
# Calcular la tabla de distribución de frecuencias
tabla_frecuencias = df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad', 'Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')

# Imprimir la tabla de distribuciones de frecuencias
print("Tabla de Distribuciones de Frecuencias:")
tabla_frecuencias
# Out:
# Tabla de Distribuciones de Frecuencias:
#     Edad  Frecuencia
# 24    18           2
# 28    19           2
# 41    21           1
# 42    23           1
# 10    24           3
# 29    25           2
# 2     26           5
# 16    27           2
# 25    30           2
# 20    31           2
# 37    32           1
# 26    33           2
# 21    34           2
# 33    35           1
# 27    36           2
# 36    37           1
# 11    38           3
# 8     39           3
# 17    40           2
# 4     41           4
# 0     42           7
# 31    43           1
# 23    44           2
# 38    45           1
# 9     46           3
# 18    47           2
# 39    49           1
# 7     50           3
# 35    51           1
# 19    52           2
# 14    54           2
# 13    56           3
# 40    57           1
# 12    58           3
# 6     59           4
# 22    60           2
# 5     61           4
# 30    62           2
# 34    63           1
# 1     65           5
# 15    67           2
# 32    69           1
# 3     70           4

# %%
tabla_frecuencias['Frec Relativa'] = tabla_frecuencias['Frecuencia'] / 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa
# 24    18           2           0.02
# 28    19           2           0.02
# 41    21           1           0.01
# 42    23           1           0.01
# 10    24           3           0.03
# 29    25           2           0.02
# 2     26           5           0.05
# 16    27           2           0.02
# 25    30           2           0.02
# 20    31           2           0.02
# 37    32           1           0.01
# 26    33           2           0.02
# 21    34           2           0.02
# 33    35           1           0.01
# 27    36           2           0.02
# 36    37           1           0.01
# 11    38           3           0.03
# 8     39           3           0.03
# 17    40           2           0.02
# 4     41           4           0.04
# 0     42           7           0.07
# 31    43           1           0.01
# 23    44           2           0.02
# 38    45           1           0.01
# 9     46           3           0.03
# 18    47           2           0.02
# 39    49           1           0.01
# 7     50           3           0.03
# 35    51           1           0.01
# 19    52           2           0.02
# 14    54           2           0.02
# 13    56           3           0.03
# 40    57           1           0.01
# 12    58           3           0.03
# 6     59           4           0.04
# 22    60           2           0.02
# 5     61           4           0.04
# 30    62           2           0.02
# 34    63           1           0.01
# 1     65           5           0.05
# 15    67           2           0.02
# 32    69           1           0.01
# 3     70           4           0.04

# %%
tabla_frecuencias['Frec Porcentual'] = tabla_frecuencias['Frecuencia'] / 100 * 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual
# 24    18           2           0.02              2.0
# 28    19           2           0.02              2.0
# 41    21           1           0.01              1.0
# 42    23           1           0.01              1.0
# 10    24           3           0.03              3.0
# 29    25           2           0.02              2.0
# 2     26           5           0.05              5.0
# 16    27           2           0.02              2.0
# 25    30           2           0.02              2.0
# 20    31           2           0.02              2.0
# 37    32           1           0.01              1.0
# 26    33           2           0.02              2.0
# 21    34           2           0.02              2.0
# 33    35           1           0.01              1.0
# 27    36           2           0.02              2.0
# 36    37           1           0.01              1.0
# 11    38           3           0.03              3.0
# 8     39           3           0.03              3.0
# 17    40           2           0.02              2.0
# 4     41           4           0.04              4.0
# 0     42           7           0.07              7.0
# 31    43           1           0.01              1.0
# 23    44           2           0.02              2.0
# 38    45           1           0.01              1.0
# 9     46           3           0.03              3.0
# 18    47           2           0.02              2.0
# 39    49           1           0.01              1.0
# 7     50           3           0.03              3.0
# 35    51           1           0.01              1.0
# 19    52           2           0.02              2.0
# 14    54           2           0.02              2.0
# 13    56           3           0.03              3.0
# 40    57           1           0.01              1.0
# 12    58           3           0.03              3.0
# 6     59           4           0.04              4.0
# 22    60           2           0.02              2.0
# 5     61           4           0.04              4.0
# 30    62           2           0.02              2.0
# 34    63           1           0.01              1.0
# 1     65           5           0.05              5.0
# 15    67           2           0.02              2.0
# 32    69           1           0.01              1.0
# 3     70           4           0.04              4.0

# %%
tabla_frecuencias['Frec Acumulada'] = tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual  Frec Acumulada
# 24    18           2           0.02              2.0               2
# 28    19           2           0.02              2.0               4
# 41    21           1           0.01              1.0               5
# 42    23           1           0.01              1.0               6
# 10    24           3           0.03              3.0               9
# 29    25           2           0.02              2.0              11
# 2     26           5           0.05              5.0              16
# 16    27           2           0.02              2.0              18
# 25    30           2           0.02              2.0              20
# 20    31           2           0.02              2.0              22
# 37    32           1           0.01              1.0              23
# 26    33           2           0.02              2.0              25
# 21    34           2           0.02              2.0              27
# 33    35           1           0.01              1.0              28
# 27    36           2           0.02              2.0              30
# 36    37           1           0.01              1.0              31
# 11    38           3           0.03              3.0              34
# 8     39           3           0.03              3.0              37
# 17    40           2           0.02              2.0              39
# 4     41           4           0.04              4.0              43
# 0     42           7           0.07              7.0              50
# 31    43           1           0.01              1.0              51
# 23    44           2           0.02              2.0              53
# 38    45           1           0.01              1.0              54
# 9     46           3           0.03              3.0              57
# 18    47           2           0.02              2.0              59
# 39    49           1           0.01              1.0              60
# 7     50           3           0.03              3.0              63
# 35    51           1           0.01              1.0              64
# 19    52           2           0.02              2.0              66
# 14    54           2           0.02              2.0              68
# 13    56           3           0.03              3.0              71
# 40    57           1           0.01              1.0              72
# 12    58           3           0.03              3.0              75
# 6     59           4           0.04              4.0              79
# 22    60           2           0.02              2.0              81
# 5     61           4           0.04              4.0              85
# 30    62           2           0.02              2.0              87
# 34    63           1           0.01              1.0              88
# 1     65           5           0.05              5.0              93
# 15    67           2           0.02              2.0              95
# 32    69           1           0.01              1.0              96
# 3     70           4           0.04              4.0             100

# %% [markdown]
# ##**Regla de sturges**
#
# 1.- Es una regla que sirve para calcular el número de clases o intervalos idóneos en los que que se debe dividir un conjunto de datos. 2.Establece que el número de clases es igual a uno más el logaritmo en base dos del número total de datos.
#
# ** * C= 1 + log²(N)* **
#
# Donde N es el tamaño de la muestra.

# %%
import math

# %%
# Volvemos a usar la lista de edades
print (edades)
# Out:
# [51, 56, 27, 19, 21, 59, 54, 44, 39, 70, 46, 25, 41, 42, 36, 24, 42, 33, 41, 41, 65, 54, 58, 18, 60, 62, 33, 57, 50, 49, 70, 46, 31, 50, 42, 44, 38, 65, 70, 19, 45, 32, 31, 59, 47, 65, 39, 36, 38, 40, 62, 37, 42, 26, 58, 67, 39, 70, 24, 61, 26, 18, 26, 61, 40, 30, 24, 38, 41, 61, 47, 27, 50, 65, 35, 60, 59, 42, 26, 52, 59, 69, 58, 42, 56, 56, 26, 61, 42, 52, 34, 65, 43, 46, 63, 34, 67, 30, 25, 23]

# %%
# Crear un DataFrame con las edades
df = pd.DataFrame({'Edad': edades})
df
# Out:
#     Edad
# 0     51
# 1     56
# 2     27
# 3     19
# 4     21
# ..   ...
# 95    34
# 96    67
# 97    30
# 98    25
# 99    23
#
# [100 rows x 1 columns]

# %%
# Calcular el número de intervalos utilizando la regla de Sturges
n = len(edades)
k = int( 1 + math.log2(100))
print("Valor de n = ", n , " \nNúmero de intervalos =", k)
# Out:
# Valor de n =  100
# Número de intervalos = 7

# %%
# Crear la tabla de frecuencias

tabla_frecuencia = pd.cut( df['Edad'], bins=k, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns = ['Clase', 'Frec']
tabla_frecuencia
# Out:
#               Clase  Frec
# 0  (40.286, 47.714]    20
# 1  (55.143, 62.571]    19
# 2  (32.857, 40.286]    16
# 3    (62.571, 70.0]    13
# 4  (25.429, 32.857]    12
# 5  (17.947, 25.429]    11
# 6  (47.714, 55.143]     9

# %%
# Ordenar la tabla de frecuencia por el intervalo
tabla_frecuencia = tabla_frecuencia.sort_values(by='Clase')
tabla_frecuencia
# Out:
#               Clase  Frec
# 5  (17.947, 25.429]    11
# 4  (25.429, 32.857]    12
# 2  (32.857, 40.286]    16
# 0  (40.286, 47.714]    20
# 6  (47.714, 55.143]     9
# 1  (55.143, 62.571]    19
# 3    (62.571, 70.0]    13

# %%
# Generar columnas siguientes
tabla_frecuencia['Frec Rel'] = tabla_frecuencia['Frec'] / n
tabla_frecuencia['Frec Porc'] = tabla_frecuencia['Frec'] / n * 100
tabla_frecuencia['Frec Ac'] = tabla_frecuencia['Frec'].cumsum()
tabla_frecuencia['Frec Rel Ac'] = tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia['Frec Porc Ac'] = tabla_frecuencia['Frec Porc'].cumsum()

# Mostrar la tabla de frecuencia
print(tabla_frecuencia)
# Out:
#               Clase  Frec  Frec Rel  Frec Porc  Frec Ac  Frec Rel Ac  \
# 5  (17.947, 25.429]    11      0.11       11.0       11         0.11
# 4  (25.429, 32.857]    12      0.12       12.0       23         0.23
# 2  (32.857, 40.286]    16      0.16       16.0       39         0.39
# 0  (40.286, 47.714]    20      0.20       20.0       59         0.59
# 6  (47.714, 55.143]     9      0.09        9.0       68         0.68
# 1  (55.143, 62.571]    19      0.19       19.0       87         0.87
# 3    (62.571, 70.0]    13      0.13       13.0      100         1.00
#
#    Frec Porc Ac
# 5          11.0
# 4          23.0
# 2          39.0
# 0          59.0
# 6          68.0
# 1          87.0
# 3         100.0

# %%
import matplotlib.pyplot as plt #impor
plt.hist(edades, alpha = 0.5)
plt.title("Historama de edades basado en la funcion de matplotlib con valores estandar")
# Out:
# Text(0.5, 1.0, 'Historama de edades basado en la funcion de matplotlib con valores estandar')

# %%
#crear un historama basado en la tabla de frecuencia
plt.hist(df['Edad'], bins=k, alpha = 0.5)
plt.title("Historama de edades basado en la regla de Struges")
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# ##**PRACTICA 5: DIAGRAMA DE CAJAS Y BIGOTES**

# %%
# basado en el LIBRO estadística para administración pagina 12
# creamos una lista vacia que representa la edad de 100 personas

edades2= []

# Hacemos un ciclo para generar 100 números aleatorios que representan la edad de las personas
for i in range(100):
    # generamos un número aleatorio con la funcion randint y lo guardamos en la variable
    # numero_aleatorio
    numero_aleatorio = random.randint( 20, 87)
    # Agregamos el número aleatorio a la lista de valores
    edades2.append(numero_aleatorio)

print(edades2)
# Out:
# [83, 25, 32, 84, 80, 50, 78, 49, 27, 78, 87, 28, 77, 34, 67, 56, 47, 58, 25, 50, 82, 41, 32, 64, 57, 64, 61, 66, 28, 83, 51, 72, 75, 23, 46, 29, 37, 66, 27, 28, 35, 45, 69, 35, 35, 69, 28, 56, 73, 22, 39, 51, 60, 50, 59, 87, 83, 41, 35, 62, 53, 21, 81, 84, 42, 42, 55, 57, 79, 70, 34, 39, 68, 26, 84, 42, 70, 85, 31, 72, 59, 49, 63, 23, 42, 43, 58, 22, 83, 63, 78, 26, 43, 61, 71, 53, 28, 55, 85, 44]

# %%
fig, (ax1,ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9,4))
bplot1 = ax1.boxplot(edades,
                     vert=True, #vertical box aligment
                     patch_artist=True) #fill with color
ax1.set_title("Edades Encuesta 1 ")

bplot2 = ax2.boxplot(edades2,
                         vert=True, #vertical box aligment
                     patch_artist=True) #fill with color
ax2.set_title("Edades Encuesta 2 ")
plt.show()

# %%
edades2.append(130)

# %%
fig, (ax1,ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9,4))
bplot1 = ax1.boxplot(edades,
                     vert=True, #vertical box aligment
                     patch_artist=True) #fill with color
ax1.set_title("Edades Encuesta 1 ")

bplot2 = ax2.boxplot(edades2,
                         vert=True, #vertical box aligment
                     patch_artist=True) #fill with color
ax2.set_title("Edades Encuesta 2 ")
plt.show()

# %% [markdown]
# ##**CONCLUSIONES**
